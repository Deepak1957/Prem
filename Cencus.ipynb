# %%
import pandas as pd
#import pandas.plotting._core.PlotAccessor
import pandas.plotting as  pl

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.figure as fig
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Cencus.csv")
print(df)
# Out:
#        ge          Workclass  Fnlwgt    Education  Education_num  \
# 0      50   Self-emp-not-inc   83311    Bachelors             13
# 1      38            Private  215646      HS-grad              9
# 2      53            Private  234721         11th              7
# 3      28            Private  338409    Bachelors             13
# 4      37            Private  284582      Masters             14
# ...    ..                ...     ...          ...            ...
# 32555  27            Private  257302   Assoc-acdm             12
# 32556  40            Private  154374      HS-grad              9
# 32557  58            Private  151910      HS-grad              9
# 32558  22            Private  201490      HS-grad              9
# 32559  52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df.head()
# Out:
#    ge          Workclass  Fnlwgt   Education  Education_num  \
# 0  50   Self-emp-not-inc   83311   Bachelors             13
# 1  38            Private  215646     HS-grad              9
# 2  53            Private  234721        11th              7
# 3  28            Private  338409   Bachelors             13
# 4  37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.isnull().sum()
# Out:
# ge                0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.nunique()
# Out:
# ge                   73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %% [raw]
# Ther we are able to see the unique value of evey attribute

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# ge              32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education_num   32560.0      10.080590       2.572709      1.0       9.0
# Capital_gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# Hours_per_week  32560.0      40.437469      12.347618      1.0      40.0
#
#                      50%       75%        max
# ge                  37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education_num       10.0      12.0       16.0
# Capital_gain         0.0       0.0    99999.0
# Capital_loss         0.0       0.0     4356.0
# Hours_per_week      40.0      45.0       99.0

# %% [markdown]
# #Value count Function

# %%
df.columns
# Out:
# Index(['ge', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df['ge'].value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: ge, Length: 73, dtype: int64

# %%
df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
df['Fnlwgt'].value_counts()
# Out:
# 123011    13
# 203488    13
# 164190    13
# 121124    12
# 148995    12
#           ..
# 68318      1
# 284211     1
# 312881     1
# 177711     1
# 229376     1
# Name: Fnlwgt, Length: 21647, dtype: int64

# %%
df['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
df['Marital_status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
df['Occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
df['Relationship'].value_counts()
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
df['Race'].value_counts()
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %%
df['Capital_gain'].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# Name: Capital_gain, Length: 119, dtype: int64

# %%
df['Hours_per_week'].value_counts()
# Out:
# 40    15216
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 92        1
# 94        1
# 87        1
# 74        1
# 82        1
# Name: Hours_per_week, Length: 94, dtype: int64

# %%
df['Native_country'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  Greece                           29
#  France                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64

# %%
df.columns
# Out:
# Index(['ge', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
#Data vicualization
sns.countplot(df["Income"],palette="coolwarm",hue="Sex",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df["Income"],palette="coolwarm",hue="Native_country",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df["Income"],palette="coolwarm",hue="Hours_per_week",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df["Income"],palette="coolwarm",hue="Capital_loss",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df["Income"],palette="coolwarm",hue="Capital_gain",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df["Income"],palette="coolwarm",hue="Relationship",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df["Income"],palette="coolwarm",hue="Occupation",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(df["Income"],palette="coolwarm",hue="Marital_status",data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# # Filling ? Values

# %%
#replace the values with mode.
#Most frequently coming string is replace to the ?

# %%
df['Workclass']= df['Workclass'].replace("?","Private")
df['Occupation']= df['Occupation'].replace("?","proof.specialty")
df['Native_country']= df['Native_country'].replace("?","United.States")

# %%
df.head()
# Out:
#    ge          Workclass  Fnlwgt   Education  Education_num  \
# 0  50   Self-emp-not-inc   83311   Bachelors             13
# 1  38            Private  215646     HS-grad              9
# 2  53            Private  234721        11th              7
# 3  28            Private  338409   Bachelors             13
# 4  37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
df["Marital_status"].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
df["Education"].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
#Label encoder use for convert the string value into numberi value.
#it made the data ready for m/l

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

# %%
df.head(9)
# Out:
#    ge  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0  33          6    2925          9             12               2
# 1  21          4   14085         11              8               0
# 2  36          4   15335          1              6               2
# 3  11          4   19354          9             12               2
# 4  20          4   17699         12             13               2
# 5  32          4    8535          6              4               3
# 6  35          6   13619         11              8               2
# 7  14          4    1318         12             13               4
# 8  25          4    8459          9             12               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
# 5           8             1     2    0             0             0
# 6           4             0     4    1             0             0
# 7          10             1     4    0           105             0
# 8           4             0     4    1            79             0
#
#    Hours_per_week  Native_country  Income
# 0              12              39       0
# 1              39              39       0
# 2              39              39       0
# 3              39               5       0
# 4              39              39       0
# 5              15              23       0
# 6              44              39       1
# 7              49              39       1
# 8              39              39       1

# %%
#Corretion of the numberic data

# %%
df.corr()
# Out:
#                       ge  Workclass    Fnlwgt  Education  Education_num  \
# ge              1.000000   0.003829 -0.078466  -0.010499       0.036547
# Workclass       0.003829   1.000000 -0.018359   0.023537       0.052015
# Fnlwgt         -0.078466  -0.018359  1.000000  -0.027082      -0.042806
# Education      -0.010499   0.023537 -0.027082   1.000000       0.359172
# Education_num   0.036547   0.052015 -0.042806   0.359172       1.000000
# Marital_status -0.266433  -0.064798  0.030163  -0.038398      -0.069338
# Occupation     -0.020929   0.255004  0.003417  -0.021274       0.109748
# Relationship   -0.263783  -0.090449  0.007005  -0.010879      -0.094145
# Race            0.028751   0.049720 -0.008964   0.014135       0.031825
# Sex             0.088863   0.095942  0.025787  -0.027349       0.012256
# Capital_gain    0.125916   0.029297 -0.004562   0.031392       0.154387
# Capital_loss    0.065058   0.015630 -0.009912   0.016111       0.084175
# Hours_per_week  0.069123   0.139553 -0.019168   0.056295       0.150098
# Native_country -0.001145  -0.007710 -0.057038   0.064291       0.050831
# Income          0.234136   0.051645 -0.010573   0.079311       0.335182
#
#                 Marital_status  Occupation  Relationship      Race       Sex  \
# ge                   -0.266433   -0.020929     -0.263783  0.028751  0.088863
# Workclass            -0.064798    0.255004     -0.090449  0.049720  0.095942
# Fnlwgt                0.030163    0.003417      0.007005 -0.008964  0.025787
# Education            -0.038398   -0.021274     -0.010879  0.014135 -0.027349
# Education_num        -0.069338    0.109748     -0.094145  0.031825  0.012256
# Marital_status        1.000000   -0.009617      0.185461 -0.068025 -0.129337
# Occupation           -0.009617    1.000000     -0.075620  0.006779  0.080328
# Relationship          0.185461   -0.075620      1.000000 -0.116052 -0.582453
# Race                 -0.068025    0.006779     -0.116052  1.000000  0.087197
# Sex                  -0.129337    0.080328     -0.582453  0.087197  1.000000
# Capital_gain         -0.075162    0.026285     -0.093141  0.024951  0.077573
# Capital_loss         -0.035235    0.017334     -0.064286  0.019366  0.049549
# Hours_per_week       -0.192647    0.080622     -0.251353  0.042318  0.231357
# Native_country       -0.023827   -0.012532     -0.005504  0.137849 -0.008125
# Income               -0.199295    0.075448     -0.250924  0.071853  0.215995
#
#                 Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# ge                  0.125916      0.065058        0.069123       -0.001145
# Workclass           0.029297      0.015630        0.139553       -0.007710
# Fnlwgt             -0.004562     -0.009912       -0.019168       -0.057038
# Education           0.031392      0.016111        0.056295        0.064291
# Education_num       0.154387      0.084175        0.150098        0.050831
# Marital_status     -0.075162     -0.035235       -0.192647       -0.023827
# Occupation          0.026285      0.017334        0.080622       -0.012532
# Relationship       -0.093141     -0.064286       -0.251353       -0.005504
# Race                0.024951      0.019366        0.042318        0.137849
# Sex                 0.077573      0.049549        0.231357       -0.008125
# Capital_gain        1.000000     -0.056966        0.101367        0.006933
# Capital_loss       -0.056966      1.000000        0.058826        0.001370
# Hours_per_week      0.101367      0.058826        1.000000       -0.002760
# Native_country      0.006933      0.001370       -0.002760        1.000000
# Income              0.340034      0.162511        0.232394        0.015845
#
#                   Income
# ge              0.234136
# Workclass       0.051645
# Fnlwgt         -0.010573
# Education       0.079311
# Education_num   0.335182
# Marital_status -0.199295
# Occupation      0.075448
# Relationship   -0.250924
# Race            0.071853
# Sex             0.215995
# Capital_gain    0.340034
# Capital_loss    0.162511
# Hours_per_week  0.232394
# Native_country  0.015845
# Income          1.000000

# %%
sns.heatmap(df.corr(),annot=True);

# %% [markdown]
# #Histogram

# %%
df.hist(figsize=(30,30),layout=(12,3),sharex=False)
# Out:
# array([[<AxesSubplot:title={'center':'ge'}>,
#         <AxesSubplot:title={'center':'Workclass'}>,
#         <AxesSubplot:title={'center':'Fnlwgt'}>],
#        [<AxesSubplot:title={'center':'Education'}>,
#         <AxesSubplot:title={'center':'Education_num'}>,
#         <AxesSubplot:title={'center':'Marital_status'}>],
#        [<AxesSubplot:title={'center':'Occupation'}>,
#         <AxesSubplot:title={'center':'Relationship'}>,
#         <AxesSubplot:title={'center':'Race'}>],
#        [<AxesSubplot:title={'center':'Sex'}>,
#         <AxesSubplot:title={'center':'Capital_gain'}>,
#         <AxesSubplot:title={'center':'Capital_loss'}>],
#        [<AxesSubplot:title={'center':'Hours_per_week'}>,
#         <AxesSubplot:title={'center':'Native_country'}>,
#         <AxesSubplot:title={'center':'Income'}>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # Boxplot

# %%
df.plot(kind="box",figsize=(30,30),layout=(12,3),sharex=False,subplots=True)
# Out:
# ge                   AxesSubplot(0.125,0.826831;0.227941x0.053169)
# Workclass         AxesSubplot(0.398529,0.826831;0.227941x0.053169)
# Fnlwgt            AxesSubplot(0.672059,0.826831;0.227941x0.053169)
# Education            AxesSubplot(0.125,0.763028;0.227941x0.053169)
# Education_num     AxesSubplot(0.398529,0.763028;0.227941x0.053169)
# Marital_status    AxesSubplot(0.672059,0.763028;0.227941x0.053169)
# Occupation           AxesSubplot(0.125,0.699225;0.227941x0.053169)
# Relationship      AxesSubplot(0.398529,0.699225;0.227941x0.053169)
# Race              AxesSubplot(0.672059,0.699225;0.227941x0.053169)
# Sex                  AxesSubplot(0.125,0.635423;0.227941x0.053169)
# Capital_gain      AxesSubplot(0.398529,0.635423;0.227941x0.053169)
# Capital_loss      AxesSubplot(0.672059,0.635423;0.227941x0.053169)
# Hours_per_week        AxesSubplot(0.125,0.57162;0.227941x0.053169)
# Native_country     AxesSubplot(0.398529,0.57162;0.227941x0.053169)
# Income             AxesSubplot(0.672059,0.57162;0.227941x0.053169)
# dtype: object

# %%
sns.countplot(df['Race'],hue='Income',data=df,palette='Blues')
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %%
sns.countplot(df['Workclass'],hue='Income',data=df,palette='Blues')
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='count'>

# %%
sns.countplot(df['Fnlwgt'],hue='Income',data=df,palette='Blues')
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='count'>

# %%
sns.countplot(df['Education'],hue='Income',data=df,palette='Blues')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(df['Education_num '],hue='Income',data=df,palette='Blues')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Education_num '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-80e70c456bdc> in <module>
# ----> 1 sns.countplot(df['Education_num '],hue='Income',data=df,palette='Blues')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Education_num '

# %%
sns.countplot(df['Marital_status'],hue='Income',data=df,palette='Blues')

# %%
sns.countplot(df['Occupation'],hue='Income',data=df,palette='Blues')

# %%
sns.countplot(df['Relationship '],hue='Income',data=df,palette='Blues')

# %%
sns.countplot(df['Sex '],hue='Income',data=df,palette='Blues')

# %%
sns.countplot(df['Capital_gain'],hue='Income',data=df,palette='Blues')

# %%
sns.countplot(df['Capital_loss'],hue='Income',data=df,palette='Blues')

# %%
sns.countplot(df['Hours_per_week'],hue='Income',data=df,palette='Blues')

# %%
sns.countplot(df['Native_country'],hue='Income',data=df,palette='Blues')

# %%
sns.countplot(df['Income'],hue='Income',data=df,palette='Blues')

# %%
df.head()
# Out:
#    ge  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0  33          6    2925          9             12               2
# 1  21          4   14085         11              8               0
# 2  36          4   15335          1              6               2
# 3  11          4   19354          9             12               2
# 4  20          4   17699         12             13               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              12              39       0
# 1              39              39       0
# 2              39              39       0
# 3              39               5       0
# 4              39              39       0

# %%
x=df.iloc[:,: -1]

# %%
x.head()
# Out:
#    ge  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0  33          6    2925          9             12               2
# 1  21          4   14085         11              8               0
# 2  36          4   15335          1              6               2
# 3  11          4   19354          9             12               2
# 4  20          4   17699         12             13               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
# 2           6             0     2    1             0             0
# 3          10             5     2    0             0             0
# 4           4             5     4    0             0             0
#
#    Hours_per_week  Native_country
# 0              12              39
# 1              39              39
# 2              39              39
# 3              39               5
# 4              39              39

# %%
y=df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Income, dtype: int32

# %% [raw]
# Spilt the data into x and y taining and tesing.
# making ready for machine learning

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=30, random_state= 0)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

model = lr.fit(x_train,y_train)
prediction = model.predict(x_test)

# %%
score = lr.score(x_test, y_test)
print(score)
# Out:
# 0.7

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators= 10, criterion = 'entropy', random_state = 0)
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
forest.score(x_train,y_train)
# Out:
# 0.9868736550876115

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
predmnb = mnb.predict(x_test)
print(accuracy_score(y_test,predmnb))
print(confusion_matrix(y_test,predmnb))
print(classification_report(y_test,predmnb))
# Out:
# 0.7333333333333333
# [[17  5]
#  [ 3  5]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81        22
#            1       0.50      0.62      0.56         8
#
#     accuracy                           0.73        30
#    macro avg       0.68      0.70      0.68        30
# weighted avg       0.76      0.73      0.74        30

# %%
svc = SVC(kernel='rbf') # kernel = 'rbf is -----by defult'
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
presvc = svc.predict(x_test)
print(accuracy_score(y_test,presvc))
print(confusion_matrix(y_test,presvc))
print(classification_report(y_test,presvc))
# Out:
# 0.7333333333333333
# [[22  0]
#  [ 8  0]]
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.85        22
#            1       0.00      0.00      0.00         8
#
#     accuracy                           0.73        30
#    macro avg       0.37      0.50      0.42        30
# weighted avg       0.54      0.73      0.62        30

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.9
# [[22  0]
#  [ 3  5]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        22
#            1       1.00      0.62      0.77         8
#
#     accuracy                           0.90        30
#    macro avg       0.94      0.81      0.85        30
# weighted avg       0.91      0.90      0.89        30

# %% [raw]
# RandomForestClassifier has good score.
# 98 percetage.
# compare to other alogrithm of machin learning
