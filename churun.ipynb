# %%
import pandas as pd

import pandas.plotting as  pl

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.figure as fig
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("churun.csv")
print(df)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    tenure  PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0       1             0              1                0               0
# 1      34             1              0                0               2
# 2       2             1              0                0               2
# 3      45             0              1                0               2
# 4       2             1              0                1               0
#
#    OnlineBackup  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0             2                 0            0            0                0
# 1             0                 2            0            0                0
# 2             2                 0            0            0                0
# 3             0                 2            2            0                0
# 4             0                 0            0            0                0
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
senior citizen is actually a categorical hence the 25%-50%-75% distribution is not proper
75 % customers have tenure less than 55 months
Average monthly charges are 64.76 whereas 25% customers pay more than 89.85 per month

# %%
df['BusinessTravel'].value_counts()

# %%
sns.countplot(df['BusinessTravel'])

# %%
df['Churn'].value_counts().plot(kind='barh',figsize=(9,6))
plt.xlabel("Count",labelpad=14)
plt.ylabel("Target variable",labelpad=14)
plt.title("count per catergory", y=1.02)
# Out:
# Text(0.5, 1.02, 'count per catergory')

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [raw]
# 1.Data is highly imbalance
# 2.so, we analyse the data with other features whil taking the targett values separately to get some insights.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [raw]
# no missing value is there.

# %% [markdown]
# # Univariate analysis

# %%
#sns.countplot(data=df, hue='Churn')

sns.countplot(df["SeniorCitizen"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.countplot(df["SeniorCitizen"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.countplot(df["Partner"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='count'>

# %%
sns.countplot(df["Dependents"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
plt.subplots(figsize=(12,4))
sns.countplot(df["tenure"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='count'>

# %%
sns.countplot(df["PhoneService"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='PhoneService', ylabel='count'>

# %%
sns.countplot(df["MultipleLines"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
sns.countplot(df["InternetService"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
sns.countplot(df["OnlineSecurity"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='OnlineSecurity', ylabel='count'>

# %%
sns.countplot(df["OnlineBackup"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='OnlineBackup', ylabel='count'>

# %%
sns.countplot(df["DeviceProtection"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='DeviceProtection', ylabel='count'>

# %%
sns.countplot(df["TechSupport"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='TechSupport', ylabel='count'>

# %%
sns.countplot(df["StreamingTV"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='StreamingTV', ylabel='count'>

# %%
sns.countplot(df["StreamingMovies"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='StreamingMovies', ylabel='count'>

# %%
sns.countplot(df["Contract"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
sns.countplot(df["PaperlessBilling"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='PaperlessBilling', ylabel='count'>

# %%
sns.countplot(df["PaymentMethod"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='PaymentMethod', ylabel='count'>

# %%
plt.subplots(figsize=(12,4))
sns.countplot(df["MonthlyCharges"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='count'>

# %%
plt.subplots(figsize=(12,4))
sns.countplot(df["TotalCharges"],palette="coolwarm",hue="Churn",data=df)
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='count'>

# %%
#Bivariate

# %%
df.hist(figsize=(30,30),layout=(21,3),sharex=False)
# Out:
# array([[<AxesSubplot:title={'center':'SeniorCitizen'}>,
#         <AxesSubplot:title={'center':'tenure'}>,
#         <AxesSubplot:title={'center':'MonthlyCharges'}>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
# ...

# %% [markdown]
# # To check correlation

# %%
dfcor = df.corr() # by which we are able to find out correlation value through which we are able to identify the correlation between data
dfcor
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %% [markdown]
# # Data visualization

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
#Label encoder use for convert the string value into numberi value.
#it made the data ready for m/l

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

# %%
dfcor = df.corr() # by which we are able to find out correlation value through which we are able to identify the correlation between data
dfcor
# Out:
#                   customerID    gender  SeniorCitizen   Partner  Dependents  \
# customerID          1.000000  0.006288      -0.002074 -0.026729   -0.012823
# gender              0.006288  1.000000      -0.001874 -0.001808    0.010517
# SeniorCitizen      -0.002074 -0.001874       1.000000  0.016479   -0.211185
# Partner            -0.026729 -0.001808       0.016479  1.000000    0.452676
# Dependents         -0.012823  0.010517      -0.211185  0.452676    1.000000
# tenure              0.008035  0.005106       0.016567  0.379697    0.159712
# PhoneService       -0.006483 -0.006488       0.008576  0.017706   -0.001762
# MultipleLines       0.004316 -0.006739       0.146185  0.142410   -0.024991
# InternetService    -0.012407 -0.000863      -0.032310  0.000891    0.044590
# OnlineSecurity      0.013292 -0.015017      -0.128221  0.150828    0.152166
# OnlineBackup       -0.003334 -0.012057      -0.013632  0.153130    0.091015
# ...

# %%
plt.figure(figsize=(16,21))
sns.heatmap(dfcor.corr(),cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(40,30),layout=(21,3),sharex=False)
# Out:
# array([[<AxesSubplot:title={'center':'customerID'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'SeniorCitizen'}>],
#        [<AxesSubplot:title={'center':'Partner'}>,
#         <AxesSubplot:title={'center':'Dependents'}>,
#         <AxesSubplot:title={'center':'tenure'}>],
#        [<AxesSubplot:title={'center':'PhoneService'}>,
#         <AxesSubplot:title={'center':'MultipleLines'}>,
#         <AxesSubplot:title={'center':'InternetService'}>],
#        [<AxesSubplot:title={'center':'OnlineSecurity'}>,
#         <AxesSubplot:title={'center':'OnlineBackup'}>,
#         <AxesSubplot:title={'center':'DeviceProtection'}>],
#        [<AxesSubplot:title={'center':'TechSupport'}>,
#         <AxesSubplot:title={'center':'StreamingTV'}>,
#         <AxesSubplot:title={'center':'StreamingMovies'}>],
#        [<AxesSubplot:title={'center':'Contract'}>,
#         <AxesSubplot:title={'center':'PaperlessBilling'}>,
# ...

# %% [markdown]
# # Boxplot

# %%
df.plot(kind="box",figsize=(30,30),layout=(12,3),sharex=False,subplots=True)
# Out:
# customerID             AxesSubplot(0.125,0.826831;0.227941x0.053169)
# gender              AxesSubplot(0.398529,0.826831;0.227941x0.053169)
# SeniorCitizen       AxesSubplot(0.672059,0.826831;0.227941x0.053169)
# Partner                AxesSubplot(0.125,0.763028;0.227941x0.053169)
# Dependents          AxesSubplot(0.398529,0.763028;0.227941x0.053169)
# tenure              AxesSubplot(0.672059,0.763028;0.227941x0.053169)
# PhoneService           AxesSubplot(0.125,0.699225;0.227941x0.053169)
# MultipleLines       AxesSubplot(0.398529,0.699225;0.227941x0.053169)
# InternetService     AxesSubplot(0.672059,0.699225;0.227941x0.053169)
# OnlineSecurity         AxesSubplot(0.125,0.635423;0.227941x0.053169)
# OnlineBackup        AxesSubplot(0.398529,0.635423;0.227941x0.053169)
# DeviceProtection    AxesSubplot(0.672059,0.635423;0.227941x0.053169)
# TechSupport             AxesSubplot(0.125,0.57162;0.227941x0.053169)
# StreamingTV          AxesSubplot(0.398529,0.57162;0.227941x0.053169)
# ...

# %% [markdown]
# # Drop the unused data

# %%
df.drop("customerID",axis=1,inplace=True)

# %%
df.drop("gender",axis=1,inplace=True)

# %%
df.drop("SeniorCitizen",axis=1,inplace=True)

# %%
df.drop("Partner",axis=1,inplace=True)

# %%
df.drop("Dependents",axis=1,inplace=True)

# %% [raw]
# Let's split the data into x and y
# dependent and indepent form.

# %%
x=df.iloc[:,: -1]

# %%
x.head()
# Out:
#    tenure  PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# 0       1             0              1                0               0
# 1      34             1              0                0               2
# 2       2             1              0                0               2
# 3      45             0              1                0               2
# 4       2             1              0                1               0
#
#    OnlineBackup  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0             2                 0            0            0                0
# 1             0                 2            0            0                0
# 2             2                 0            0            0                0
# 3             0                 2            2            0                0
# 4             0                 0            0            0                0
#
# ...

# %%
y=df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 30)

# %% [markdown]
# # StandardScalar

# %%
from sklearn.preprocessing import StandardScaler
# creating a standard scaler
sc = StandardScaler()
# feeding independents sets into the standard scaler
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report


from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf') # kernel = 'rbf is -----by defult'
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
presvc = svc.predict(x_test)
print(accuracy_score(y_test,presvc))
print(confusion_matrix(y_test,presvc))
print(classification_report(y_test,presvc))
# Out:
# 0.78708303761533
# [[925  76]
#  [224 184]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86      1001
#            1       0.71      0.45      0.55       408
#
#     accuracy                           0.79      1409
#    macro avg       0.76      0.69      0.71      1409
# weighted avg       0.78      0.79      0.77      1409

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.759403832505323
# [[875 126]
#  [213 195]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84      1001
#            1       0.61      0.48      0.53       408
#
#     accuracy                           0.76      1409
#    macro avg       0.71      0.68      0.69      1409
# weighted avg       0.75      0.76      0.75      1409

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators= 10, criterion = 'entropy', random_state = 0)
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
forest.score(x_train,y_train)
# Out:
# 0.9767483138090167

# %% [markdown]
# # Decision tree classifier

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# %%
# Train Decision Tree Classifer
clf = clf.fit(x_train,y_train)

# %%
#Predict the response for test dataset
y_pred = clf.predict(x_test)

# %%
# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7352732434350603
