# %%
import pandas as pd
#import pandas.plotting._core.PlotAccessor
import pandas.plotting as  pl

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.figure as fig
import seaborn as sns
#import sklearn.preprocessing.LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Insurance.csv")
print(df)
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.head(10)
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
# 5                 256   39         104594       12-10-2006           OH
# 6                 137   34         413978       04-06-2000           IN
# 7                 165   37         429027       03-02-1990           IL
# 8                  27   33         485665       05-02-1997           IL
# 9                 212   42         636550       25-07-2011           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %% [raw]
# all object data types are string data types.
# we need encoder for all the string into numeric form.
# By which we can make data for learn the data by machine.

# %%
#By using label encoder we can covert string into the numberic form.
#if data has been unable to know how many time that sting will come in the data.

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

# %%
df.head() # all data are in the form of numberic form.
# Out:
#    months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                 299   29            480               532             2
# 1                 212   23            257               821             1
# 2                 123   10            672               186             2
# 3                 239   22            140               766             0
# 4                 212   25            286               181             0
#
#    policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0           1                  1                1406.91               1
# 1           1                  2                1197.22               5
# 2           0                  2                1413.14               5
# 3           1                  2                1415.74               6
# 4           2                  1                1583.91               6
#
#    insured_zip  ...  police_report_available  total_claim_amount  \
# ...

# %% [raw]
# object we need to drop from the dataset for using the data

# %%
df.drop("policy_bind_date", axis = 1, inplace = True)

# %%
df.drop("policy_state", axis = 1, inplace = True)

# %%
df.drop("policy_csl", axis = 1, inplace = True)

# %%
df.drop("insured_sex", axis = 1, inplace = True)

# %%
df.drop("insured_education_level", axis = 1, inplace = True)

# %%
df.drop("insured_occupation", axis = 1, inplace = True)

# %%
df.drop("insured_hobbies", axis = 1, inplace = True)

# %%
df.drop("incident_date", axis = 1, inplace = True)

# %%
df.drop("collision_type", axis = 1, inplace = True)

# %%
df.drop("incident_severity", axis = 1, inplace = True)

# %%
df.drop("authorities_contacted", axis = 1, inplace = True)

# %%
df.drop("incident_state", axis = 1, inplace = True)

# %%
df.drop("incident_city", axis = 1, inplace = True)

# %%
df.drop("incident_location", axis = 1, inplace = True)

# %%
df.drop("property_damage", axis = 1, inplace = True)

# %%
df.drop("police_report_available", axis = 1, inplace = True)

# %%
df.drop("auto_model", axis = 1, inplace = True)

# %%
df.drop("fraud_reported", axis = 1, inplace = True)

# %%
df.describe()
# Out:
#        policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# count        1000.000000            1000.000000     1000.000000  1000.000000
# mean            0.965000            1256.406150        1.900000   496.321000
# std             0.805247             244.167395        1.917205   287.276417
# min             0.000000             433.330000        0.000000     0.000000
# 25%             0.000000            1089.607500        1.000000   247.750000
# 50%             1.000000            1257.200000        1.000000   496.500000
# 75%             2.000000            1415.695000        1.000000   744.250000
# max             2.000000            2047.590000       10.000000   994.000000
#
#        insured_relationship  capital-gains  capital-loss  incident_type  \
# count           1000.000000    1000.000000   1000.000000    1000.000000
# mean               2.416000      82.924000    261.197000       1.172000
# ...

# %% [raw]
# mean and std devation has huge diffrence so, most of columns has skewness is persent.
# for example age has diffrence of -+ 9 std in the data.
# due to standar devition it will in the data there has skwness in the data
# outlier is also present but not that much, But present.

# %% [markdown]
# # data droping from the data set

# %% [raw]
# We need to drop some data from the data set those are not come in use to know the insurance fraud.
# Data are need to drop is months_as_customer,age,policy_number,auto_year,_c39

# %%
df.drop("months_as_customer", axis = 1, inplace = True)

# %%
df.drop("age", axis = 1, inplace = True)

# %%
df.drop("policy_number", axis = 1, inplace = True)

# %%
df.drop("auto_year", axis = 1, inplace = True)

# %%
df.drop("_c39", axis = 1, inplace = True)

# %%
df.head()
# Out:
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                  1                1406.91               1          486
# 1                  2                1197.22               5          519
# 2                  2                1413.14               5            6
# 3                  2                1415.74               6          812
# 4                  1                1583.91               6          850
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0            187           353              2
# 1                     2              0           353              3
# 2                     3             63           353              0
# 3                     4            153            98              2
# 4                     4            265           211              3
#
#    incident_hour_of_the_day  number_of_vehicles_involved  bodily_injuries  \
# ...

# %%
df.dtypes
# Out:
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_relationship             int32
# capital-gains                    int64
# capital-loss                     int64
# incident_type                    int32
# incident_hour_of_the_day         int64
# number_of_vehicles_involved      int64
# bodily_injuries                  int64
# witnesses                        int64
# total_claim_amount               int64
# injury_claim                     int64
# property_claim                   int64
# vehicle_claim                    int64
# auto_model                       int32
# dtype: object

# %%
df.shape
# Out:
# (1000, 17)

# %% [raw]
# Machine learning algorithm has been used from our side analysis is Classifier.
# becasue of there has three types of claims injury_claim,property_claim,vehicle_claim

# %%
df.injury_claim
# Out:
# 0      258
# 1       46
# 2      337
# 3      245
# 4       70
#       ...
# 995    624
# 996    630
# 997    324
# 998    168
# 999     17
# Name: injury_claim, Length: 1000, dtype: int64

# %%
print(list(df.keys()))
# Out:
# ['policy_deductable', 'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_relationship', 'capital-gains', 'capital-loss', 'incident_type', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'total_claim_amount_t']

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# policy_deductable              0.063505
# policy_annual_premium          0.004402
# umbrella_limit                 1.936066
# insured_zip                    0.001683
# insured_relationship           0.077488
# capital-gains                  0.894996
# capital-loss                  -0.810352
# incident_type                  0.101507
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# bodily_injuries                0.014777
# witnesses                      0.019636
# total_claim_amount             0.014526
# injury_claim                   0.105325
# property_claim                 0.071055
# vehicle_claim                  0.014526
# total_claim_amount_t           0.014526
# dtype: float64

# %% [raw]
# Not that much skweness is present

# %% [markdown]
# # Visualization

# %%
sns.heatmap(df.isnull())# null value is not available at the this data set.
# Out:
# <AxesSubplot:>

# %% [markdown]
# # To check correlation

# %%
dfcor = df.corr() 
dfcor
# Out:
#                              policy_deductable  policy_annual_premium  \
# policy_deductable                     1.000000               0.001624
# policy_annual_premium                 0.001624               1.000000
# umbrella_limit                        0.009402              -0.007334
# insured_zip                          -0.004227               0.031369
# insured_relationship                 -0.025468               0.001925
# capital-gains                         0.022064               0.000041
# capital-loss                         -0.013690               0.031906
# incident_type                        -0.036759               0.053603
# incident_hour_of_the_day              0.066442              -0.001578
# number_of_vehicles_involved           0.043148              -0.045991
# bodily_injuries                      -0.020129               0.026780
# witnesses                             0.074994               0.002332
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,14))
sns.heatmap(dfcor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
df['policy_deductable'].value_counts()
# Out:
# 1    351
# 0    342
# 2    307
# Name: policy_deductable, dtype: int64

# %%
sns.countplot(x="policy_deductable", hue="total_claim_amount_t",data=df)
# Out:
# <AxesSubplot:xlabel='policy_deductable', ylabel='count'>

# %%
df['policy_annual_premium'].value_counts()

# %%
sns.distplot(df["policy_annual_premium"])
# Out:
# <AxesSubplot:xlabel='policy_annual_premium', ylabel='Density'>

# %%
df['umbrella_limit'].value_counts()

# %%
sns.distplot(df["umbrella_limit"])
# Out:
# <AxesSubplot:xlabel='umbrella_limit', ylabel='Density'>

# %%
df['insured_zip'].value_counts()

# %%
sns.distplot(df["insured_zip"])
# Out:
# <AxesSubplot:xlabel='insured_zip', ylabel='Density'>

# %%
df['insured_relationship'].value_counts()

# %%
sns.distplot(df["insured_relationship"])
# Out:
# <AxesSubplot:xlabel='insured_relationship', ylabel='Density'>

# %%
df['capital-gains'].value_counts()
# Out:
# 0      508
# 136      5
# 171      4
# 281      4
# 160      3
#       ...
# 174      1
# 317      1
# 172      1
# 318      1
# 337      1
# Name: capital-gains, Length: 338, dtype: int64

# %%
sns.distplot(df["capital-gains"])
# Out:
# <AxesSubplot:xlabel='capital-gains', ylabel='Density'>

# %%
df['incident_type'].value_counts()
# Out:
# 0    419
# 2    403
# 3     94
# 1     84
# Name: incident_type, dtype: int64

# %%
sns.distplot(df["incident_type"])
# Out:
# <AxesSubplot:xlabel='incident_type', ylabel='Density'>

# %%
df['incident_hour_of_the_day'].value_counts()
# Out:
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 4     46
# 13    46
# 10    46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 7     40
# 19    40
# 12    40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: incident_hour_of_the_day, dtype: int64

# %%
sns.distplot(df["incident_hour_of_the_day"])
# Out:
# <AxesSubplot:xlabel='incident_hour_of_the_day', ylabel='Density'>

# %%
df['number_of_vehicles_involved'].value_counts()
# Out:
# 0    581
# 2    358
# 3     31
# 1     30
# Name: number_of_vehicles_involved, dtype: int64

# %%
sns.distplot(df["number_of_vehicles_involved"])
# Out:
# <AxesSubplot:xlabel='number_of_vehicles_involved', ylabel='Density'>

# %%
df['bodily_injuries'].value_counts()
# Out:
# 0    340
# 2    332
# 1    328
# Name: bodily_injuries, dtype: int64

# %%
sns.distplot(df["bodily_injuries"])
# Out:
# <AxesSubplot:xlabel='bodily_injuries', ylabel='Density'>

# %%
df['witnesses'].value_counts()
# Out:
# 1    258
# 2    250
# 0    249
# 3    243
# Name: witnesses, dtype: int64

# %%
sns.distplot(df["witnesses"])
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='Density'>

# %%
df['injury_claim'].value_counts()
# Out:
# 0      25
# 19      7
# 35      7
# 188     5
# 29      5
#        ..
# 294     1
# 295     1
# 296     1
# 297     1
# 637     1
# Name: injury_claim, Length: 638, dtype: int64

# %%
sns.distplot(df["injury_claim"])
# Out:
# <AxesSubplot:xlabel='injury_claim', ylabel='Density'>

# %%
df['property_claim'].value_counts()
# Out:
# 0      19
# 50      6
# 417     5
# 35      5
# 36      5
#        ..
# 392     1
# 393     1
# 394     1
# 395     1
# 312     1
# Name: property_claim, Length: 626, dtype: int64

# %%
sns.distplot(df["property_claim"])
# Out:
# <AxesSubplot:xlabel='property_claim', ylabel='Density'>

# %%
df['total_claim_amount_t'].value_counts()
# Out:
# 78     7
# 33     6
# 70     5
# 410    5
# 205    5
#       ..
# 460    1
# 459    1
# 458    1
# 453    1
# 0      1
# Name: total_claim_amount_t, Length: 726, dtype: int64

# %%
sns.distplot(df["total_claim_amount_t"])
# Out:
# <AxesSubplot:xlabel='total_claim_amount_t', ylabel='Density'>

# %%
df['vehicle_claim'].value_counts()
# Out:
# 78     7
# 33     6
# 70     5
# 410    5
# 205    5
#       ..
# 460    1
# 459    1
# 458    1
# 453    1
# 0      1
# Name: vehicle_claim, Length: 726, dtype: int64

# %%
sns.distplot(df["vehicle_claim"])
# Out:
# <AxesSubplot:xlabel='vehicle_claim', ylabel='Density'>

# %%
#We replace the colunms for spliting the data.
df['total_claim_amount_t'] = df ['total_claim_amount']

# %%
df.head()
# Out:
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                  1                1406.91               1          486
# 1                  2                1197.22               5          519
# 2                  2                1413.14               5            6
# 3                  2                1415.74               6          812
# 4                  1                1583.91               6          850
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0            187           353              2
# 1                     2              0           353              3
# 2                     3             63           353              0
# 3                     4            153            98              2
# 4                     4            265           211              3
#
#    incident_hour_of_the_day  number_of_vehicles_involved  bodily_injuries  \
# ...

# %%
#Spliting the data into x and y
x=df.iloc[:,: -1]

# %%
x.head()
# Out:
#    policy_deductable  policy_annual_premium  umbrella_limit  insured_zip  \
# 0                  1                1406.91               1          486
# 1                  2                1197.22               5          519
# 2                  2                1413.14               5            6
# 3                  2                1415.74               6          812
# 4                  1                1583.91               6          850
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0            187           353              2
# 1                     2              0           353              3
# 2                     3             63           353              0
# 3                     4            153            98              2
# 4                     4            265           211              3
#
#    incident_hour_of_the_day  number_of_vehicles_involved  bodily_injuries  \
# ...

# %%
y=df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    545
# 1     38
# 2    116
# 3    521
# 4     66
# Name: total_claim_amount_t, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 30)

# %% [markdown]
# # StandardScalar

# %%
from sklearn.preprocessing import StandardScaler
# creating a standard scaler
sc = StandardScaler()
# feeding independents sets into the standard scaler
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
# creating the Linear Regression model
lR = LinearRegression()
# putting the training data to the model
lR.fit(x_train, y_train)
y_pred_lR = lR.predict(x_test)
lR.score(x_train,y_train)
# Out:
# 1.0

# %%
pred=lR.predict(x_test)
print ("predict the result of fraud:",pred)
print("actual fraud",y_test)
# Out:
# predict the result of fraud: [613.57765949 358.10296913 197.54772894 349.01493667 311.65302543
#  687.29170058 558.03968332  34.97292599 308.62368127 464.13001454
#  306.6041185  418.68985222 701.42863997 531.78536732 518.65820932
#  717.58514213 330.83887174  91.52068354 626.70481749 473.218047
#  734.75142567 434.84635438 410.61160114 512.59952101  19.82620522
#  681.23301227 376.27903406  86.47177661 340.93668559  56.17833507
#  630.74394303 590.35268764 601.46028287 478.26695392 434.84635438
#  326.7997462  154.1271294  539.8636184  123.83368785 518.65820932
#  295.49652327 293.4769605  453.0224193  180.3814454  264.19330034
#  561.06902748 295.49652327  46.08052122  79.40330692 342.95624836
#  133.9315017  151.09778524  31.94358183 359.11275052 100.608716
#   71.32505584 115.75543677 603.47984564 232.89007741 564.09837163
#  257.12483065 214.71401249  47.09030261 394.45509898 334.87799728
#  495.43323747 695.36995166  46.08052122 311.65302543 377.28881544
# ...

# %%
#Error metrics for find the error algorithm
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
print('error')
print('mean absoulte error', mean_absolute_error(y_test,pred))
print("mean squared error",mean_squared_error(y_test,pred))

print("root mean squared error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# mean absoulte error 17.029999999999976
# mean squared error 294.1428477116834
# root mean squared error 17.150593217486193

# %% [markdown]
# # Support Vector Regression

# %%
from sklearn.svm import SVR
# creating the model
svr = SVR()
# feeding the training data to the model
svr.fit(x_train, y_train)
# predicting the test set results
y_pred_svr = svr.predict(x_test)
svr.score(x_train,y_train)
# Out:
# 0.2939725670839145

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(x_train, y_train)
# Predicting a new result
y_pred = regressor.predict(x_test)
regressor.score(x_train,y_train)
# Out:
# 0.9999922867934669

# %% [raw]
# Conclusion is that linear regressor and random forest regressor both can be use for prediction.
# lR = 1.0
# Rfr = 99
